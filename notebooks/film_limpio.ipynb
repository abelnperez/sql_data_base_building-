# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
films = pd.read_csv('film.csv', encoding='latin1')
df = films.copy()
df.tail()
# Out:
#      film_id              title  \
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 998  A Fateful Reflection of a Waitress And a Boat ...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id  original_language_id  rental_duration  rental_rate  length  \
# 995            1                   NaN                6         0.99     183
# 996            1                   NaN                4         0.99     179
# 997            1                   NaN                6         0.99     105
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   film_id               1000 non-null   int64
#  1   title                 1000 non-null   object
#  2   description           1000 non-null   object
#  3   release_year          1000 non-null   int64
#  4   language_id           1000 non-null   int64
#  5   original_language_id  0 non-null      float64
#  6   rental_duration       1000 non-null   int64
#  7   rental_rate           1000 non-null   float64
#  8   length                1000 non-null   int64
#  9   replacement_cost      1000 non-null   float64
#  10  rating                1000 non-null   object
#  11  special_features      1000 non-null   object
#  12  last_update           1000 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 495.3 KB

# %%
df.columns = [c.lower() for c in df.columns] #con esto ponemos todo en minusculas son buenas practicas

# %%
df.columns = df.columns.str.strip() # Ahora eliminamos espacios en blanco al principio y al final de los nombres de las columnas

# %%
df.duplicated().sum()  #Duplicados del DataFrame
# Out:
# 0

# %%
df.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                   NaN                6         0.99      86
# 1            1                   NaN                3         4.99      48
# 2            1                   NaN                7         2.99      50
# 3            1                   NaN                5         2.99     117
# ...

# %%
df['rating'].unique()
# Out:
# array(['PG', 'G', 'NC-17', 'PG-13', 'R'], dtype=object)

# %%
# Defino un diccionario para mapear los valores existentes a los nuevos valores
mapeo = {
    'G': 'G (General Audiences)',
    'PG': 'PG (Parental Guidance Suggested)',
    'PG-13': 'PG-13 (Parents Strongly Cautioned)',
    'NC-17': 'NC-17 (Adults Only)',
    'R': 'R (Restricted)'
}

# Actualizo la columna "rating" utilizando el diccionario de mapeo
df['rating'] = df['rating'].replace(mapeo)

# %%
df['rating'].unique()
# Out:
# array(['PG (Parental Guidance Suggested)', 'G (General Audiences)',
#        'NC-17 (Adults Only)', 'PG-13 (Parents Strongly Cautioned)',
#        'R (Restricted)'], dtype=object)

# %%
df.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                   NaN                6         0.99      86
# 1            1                   NaN                3         4.99      48
# 2            1                   NaN                7         2.99      50
# 3            1                   NaN                5         2.99     117
# ...

# %%
df[df['language_id'].duplicated(keep=False)]
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df['language_id'].unique()
# Out:
# array([1], dtype=int64)

# %%
df.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'original_language_id', 'rental_duration', 'rental_rate', 'length',
#        'replacement_cost', 'rating', 'special_features', 'last_update'],
#       dtype='object')

# %%
df = df.drop(['original_language_id'], axis=1) #EMILINAR COLUMNA

# %%
df = df.drop(["last_update"], axis=1) #EMILINAR COLUMNA

# %%
df['title'].nunique() #VALORES UNICOS
# Out:
# 1000

# %%
df.head(33)
# Out:
#     film_id                 title  \
# 0         1      ACADEMY DINOSAUR
# 1         2        ACE GOLDFINGER
# 2         3      ADAPTATION HOLES
# 3         4      AFFAIR PREJUDICE
# 4         5           AFRICAN EGG
# 5         6          AGENT TRUMAN
# 6         7       AIRPLANE SIERRA
# 7         8       AIRPORT POLLOCK
# 8         9         ALABAMA DEVIL
# 9        10      ALADDIN CALENDAR
# 10       11       ALAMO VIDEOTAPE
# 11       12        ALASKA PHANTOM
# 12       13           ALI FOREVER
# 13       14        ALICE FANTASIA
# 14       15          ALIEN CENTER
# 15       16       ALLEY EVOLUTION
# 16       17            ALONE TRIP
# 17       18         ALTER VICTORY
# 18       19          AMADEUS HOLY
# 19       20   AMELIE HELLFIGHTERS
# 20       21       AMERICAN CIRCUS
# 21       22     AMISTAD MIDSUMMER
# 22       23  ANACONDA CONFESSIONS
# 23       24      ANALYZE HOOSIERS
# 24       25           ANGELS LIFE
# 25       26        ANNIE IDENTITY
# ...

# %%
df.to_csv('../src/film_limpio.csv', index=False) # guardamos en la carpeta src el archivo limpio.

# %%
# %pip install SQLAlchemy
# %pip install pymysql

# %%
from sqlalchemy import create_engine
import pymysql

# %%
str_conn = f'mysql+pymysql://root:a1b2e3l4_IRONHACK@localhost:3306/movies'
cursor = create_engine(str_conn)

# %%
df.to_sql(name='film',
            con=cursor,
            if_exists='replace',
            index=False)
# Out:
# 1000
